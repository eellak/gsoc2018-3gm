# %%
import pyLDAvis
import pyLDAvis.sklearn
pyLDAvis.enable_notebook()
import warnings; warnings.simplefilter('ignore')

from lda import *
# Out:
# Topic 0:
# παρ εξής πε υπουργού οντότητα
# 35.txt
# 26.txt
# 36.txt
# Topic 1:
# τροποποιείται πρόσωπο επωνυμία δημοσίου υποχρεώσεις
# 14.txt
# 7.txt
# 31.txt
# Topic 2:
# κορέας λαϊκή δημοκρατία λαϊκής δημοκρατίας
# 18.txt
# 32.txt
# 8.txt
# Topic 3:
# περιοχή διατάγματος πρώτο αριθμ παρ
# 11.txt
# 34.txt
# 35.txt
# Topic 4:
# πράξης φράση κώδικα παρ δήλωση
# 17.txt
# 19.txt
# 3.txt
# Topic 5:
# πληροφορικής υποστήριξης σώματος ειδικότητας τεχνικής
# 10.txt
# 22.txt
# 20.txt
# Topic 6:
# αστυνομίας ελληνικής αξιωματικοί εξής αστυνομικού
# 23.txt
# 22.txt
# 5.txt
# Topic 7:
# διατάγματος ελλάδας υπουργό δημοσίευση αθήνα
# 5.txt
# 29.txt
# 23.txt
# Topic 8:
# πακέτου διοργανωτής ταξιδιού πακέτο οργανωμένου
# 6.txt
# 15.txt
# 5.txt
# Topic 9:
# ενέργειας θερμικής ηλεκτρικής παραγωγής διανομής
# 25.txt
# 3.txt
# 24.txt
# ...

# %% [markdown]
# Visualize topics with pyLDAvis

# %%
pyLDAvis.sklearn.prepare(lda_model, tfidf, tfidf_vectorizer)
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 4      43.206930        1       1  0.045877  0.009308
# 5      15.136629        1       2  0.109448 -0.016585
# 2      15.028278        1       3 -0.142325 -0.022518
# 3      11.305268        1       4 -0.030149  0.062450
# 1       5.541770        1       5  0.006624 -0.000035
# 8       4.364792        1       6  0.009381  0.004301
# 9       2.357217        1       7 -0.003098 -0.005874
# 0       1.019721        1       8  0.012512 -0.010966
# 7       1.019702        1       9 -0.012743 -0.013644
# 6       1.019695        1      10  0.004473 -0.006437, topic_info=     Category      Freq           Term     Total  loglift  logprob
# term
# 656   Default  2.000000            παρ  2.000000  30.0000  30.0000
# 336   Default  1.000000      ενέργειας  1.000000  29.0000  29.0000
# 888   Default  1.000000          τμήμα  1.000000  28.0000  28.0000
# ...
